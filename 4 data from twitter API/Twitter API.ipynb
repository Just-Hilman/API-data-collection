# %% [markdown]
# ## Objectives
#
# *   Collect Twitter data using an API
# *   Store the data as a CSV, JSON, and XML files

# %% [markdown]
# ## Imports
#
# Import any additional libraries may need here.

# %%
import requests
import pandas as pd
import json

# %% [markdown]
# ## Extract Data Using an API

# %% [markdown]
# Using Twitter-API we will extract Twitter public and private data API for search, Tweets, users, followers, images, media and more.

# %% [markdown]
# ### Call the API

# %%
url = "https://twitter-data1.p.rapidapi.com/Followers/"

querystring = {"id":"553468671", "count":"41"}

headers = {
    "X-RapidAPI-Key": "a6129818camshba593fc1a0fb7dbp109dabjsn602bb7495377",
    "X-RapidAPI-Host": "twitter-data1.p.rapidapi.com"
}

response = requests.request("GET", url, headers=headers, params=querystring)

# %%
print(response)
# Out:
# <Response [200]>

# %%
data = json.loads(requests.get(url, headers=headers, params=querystring).text)

# %%
data

# %%
data_to_collect = data["data"]["user"]["result"]["timeline"]["timeline"]["instructions"][3]["entries"]

# %%
data_to_collect[0:-2]

# %%
user_data = pd.DataFrame(columns=["id", "rest_id", "name", "user_name", "created_at", "likes_count", "followers_count", "following_count", "media_count", "status_count", "verified"])

for data in data_to_collect[0:-2]:
    id = data["content"]["itemContent"]["user_results"]["result"]["id"]
    rest_id = data["content"]["itemContent"]["user_results"]["result"]["rest_id"]
    name = data["content"]["itemContent"]["user_results"]["result"]["legacy"]["name"]
    user_name = data["content"]["itemContent"]["user_results"]["result"]["legacy"]["screen_name"]
    created_at = data["content"]["itemContent"]["user_results"]["result"]["legacy"]["created_at"]
    likes_count = data["content"]["itemContent"]["user_results"]["result"]["legacy"]["favourites_count"]
    followers_count = data["content"]["itemContent"]["user_results"]["result"]["legacy"]["followers_count"]
    following_count = data["content"]["itemContent"]["user_results"]["result"]["legacy"]["friends_count"]
    media_count = data["content"]["itemContent"]["user_results"]["result"]["legacy"]["media_count"]
    status_count = data["content"]["itemContent"]["user_results"]["result"]["legacy"]["statuses_count"]
    verified = data["content"]["itemContent"]["user_results"]["result"]["legacy"]["verified"]
    user_data = user_data.append({"id": id, "rest_id": rest_id, "name": name, "user_name": user_name, "created_at": created_at, "likes_count": likes_count, "followers_count": followers_count, "following_count": following_count, "media_count": media_count, "status_count": status_count, "verified": verified}, ignore_index=True)

# %%
user_data
# Out:
#                                   id              rest_id  \
# 0               VXNlcjoxOTYxNzQ0NTE=            196174451
# 1   VXNlcjoxNDg2NjE2MDgzNjQ5ODEwNDM4  1486616083649810438
# 2               VXNlcjoxNTgxMzE0MA==             15813140
# 3               VXNlcjoxNjQxOTE0OTk=            164191499
# 4   VXNlcjoxMjg4OTc4ODkxMDA5MTc1NTUy  1288978891009175552
# 5               VXNlcjoyMzY1MDc3NjE0           2365077614
# 6               VXNlcjo1NzAzOTA5NjM=            570390963
# 7               VXNlcjoyMjE0OTEzMTI4           2214913128
# 8               VXNlcjoyNDI0NDQ0NjAx           2424444601
# 9               VXNlcjoyMjQwNTAxODU2           2240501856
# 10              VXNlcjozNDU3MjczNjMz           3457273633
# 11              VXNlcjozMjIzODczODk2           3223873896
# 12              VXNlcjozMjMxODcwMzI2           3231870326
# 13              VXNlcjozMTk3NjI3NzIw           3197627720
# 14              VXNlcjoxMjc4OTY1NjQx           1278965641
# 15              VXNlcjo5ODU3MDY4MDM=            985706803
# 16              VXNlcjozMTA0MjA4NTA1           3104208505
# 17              VXNlcjoxMDE0OTQ2NjM=            101494663
# 18              VXNlcjoyNTAwOTIwNTQ3           2500920547
# 19              VXNlcjo1NDg5MDQ4MjQ=            548904824
# 20              VXNlcjoyODU3ODA2NDQ1           2857806445
# 21              VXNlcjoyODM1NzkwMzY0           2835790364
# 22              VXNlcjozMzI2MTgwODE=            332618081
# 23              VXNlcjo2MjM4ODI4MjA=            623882820
# 24              VXNlcjo2MjA1MTQzOTI=            620514392
# 25              VXNlcjoyNTM0MzI4NDky           2534328492
# 26              VXNlcjoyMzU1NzQzMDQw           2355743040
# 27              VXNlcjo1NTQ5Mjk1NDI=            554929542
# 28              VXNlcjoxNDcxNTY2NzY5           1471566769
# 29              VXNlcjoxMDg5MDg5NTM0           1089089534
# 30              VXNlcjoxOTc3NjMwNDE=            197763041
# 31              VXNlcjoyOTE3MDI3NDk=            291702749
# 32              VXNlcjo1NzE3NDExNzk=            571741179
# 33              VXNlcjo1NzMyNjI4Mjc=            573262827
# 34              VXNlcjoxODM0ODQ5MDY=            183484906
# 35              VXNlcjo1NTg0NjMzODY=            558463386
# 36              VXNlcjoxNzgyNzY2OTE=            178276691
# 37              VXNlcjo0NzE1MjQ5MzE=            471524931
# 38              VXNlcjoyODYxMzk3NTM=            286139753
# 39              VXNlcjozMTAwNzQxNTA=            310074150
# 40              VXNlcjoyNjkyNTkzNzU=            269259375
#
#                     name        user_name                      created_at  \
# 0           Darwish Hero      boss_somali  Tue Sep 28 14:20:53 +0000 2010
# 1               Seto aji  Setoaji27446417  Thu Jan 27 08:25:27 +0000 2022
# 2      Google Cloud Tech  GoogleCloudTech  Mon Aug 11 20:08:12 +0000 2008
# 3                 gregor     PrakosoGrego  Thu Jul 08 07:37:55 +0000 2010
# 4                    ニタ💌      Nitadevianp  Thu Jul 30 23:25:08 +0000 2020
# 5      JNE Customer Care          JNECare  Fri Feb 28 04:46:02 +0000 2014
# 6          Michal Curran      19mustang99  Thu May 03 21:41:56 +0000 2012
# 7       Diah Ayu Hidayah   DiahUbaidillah  Tue Nov 26 01:11:35 +0000 2013
# 8               Omrudies         Omrudies  Wed Apr 02 22:51:18 +0000 2014
# 9         Bobotoh Persib       Dhe_Elna29  Wed Dec 11 09:42:07 +0000 2013
# 10       Sri Robiyatul A       ARobiyatul  Sat Sep 05 08:11:48 +0000 2015
# 11        Muhamad Parhan        parhan348  Sat May 23 05:17:55 +0000 2015
# 12    syarief ikhsan 135      IkhsanTrhee  Sun May 31 17:33:45 +0000 2015
# 13             Nia Bella      niabella616  Sat May 16 15:38:46 +0000 2015
# 14               karnika      nicakarnica  Mon Mar 18 22:58:05 +0000 2013
# 15           RYU COMPANY    astiyulianti4  Mon Dec 03 01:15:47 +0000 2012
# 16        Muslimah_Shop    momen_infinity  Mon Mar 23 03:55:11 +0000 2015
# 17        BANDUNG ᮘᮔ᮪ᮓᮥᮀ          infobdg  Sun Jan 03 15:01:27 +0000 2010
# 18                Ciwaru    ciwarupayment  Sat May 17 07:43:50 +0000 2014
# 19          Indosat Care      IndosatCare  Mon Apr 09 03:21:56 +0000 2012
# 20           Intan cLara  ff7a77bca04f448  Thu Oct 16 08:21:16 +0000 2014
# 21                  tian    saltshimazaki  Tue Sep 30 08:59:12 +0000 2014
# 22                  Dera      Derra_Deira  Sun Jul 10 04:02:26 +0000 2011
# 23            Rofi kahfi       momay_opay  Sun Jul 01 14:42:23 +0000 2012
# 24            Nona zakta    nona_triadjie  Thu Jun 28 01:28:59 +0000 2012
# 25        endang jamilah  nun_jamilaku_46  Fri May 30 06:27:28 +0000 2014
# 26         #ShishaMaster  ShishaMaster_ID  Sat Feb 22 04:05:14 +0000 2014
# 27           Hady dolken    hadicahyadi94  Mon Apr 16 04:00:48 +0000 2012
# 28              porororo     winniwidiana  Fri May 31 07:12:03 +0000 2013
# 29         mitha juliana         mithataw  Mon Jan 14 13:50:04 +0000 2013
# 30  SMK NEGERI 6 BANDUNG         SMKN6BDG  Sat Oct 02 11:37:49 +0000 2010
# 31               sisendi        sendii_ry  Mon May 02 13:45:11 +0000 2011
# 32     khabayan iskandar     khabayan1933  Sat May 05 11:11:37 +0000 2012
# 33       iip noerhanipah  iip_noerhanipah  Mon May 07 01:25:23 +0000 2012
# 34    firmansyah hamdani   firman_hamdani  Fri Aug 27 03:09:37 +0000 2010
# 35           inisial 'W'      wildanAK_47  Fri Apr 20 06:34:50 +0000 2012
# 36       Kurniawan Agung      retypevolta  Sat Aug 14 09:24:29 +0000 2010
# 37              wahyudin  wahyudinhungkul  Mon Jan 23 00:00:54 +0000 2012
# 38                 Grego       sumblahong  Fri Apr 22 12:28:56 +0000 2011
# 39              Rounggur   runggupasaribu  Fri Jun 03 04:38:35 +0000 2011
# 40       Yasir Jamaludin   yasirjamaludin  Sun Mar 20 12:04:19 +0000 2011
#
#    likes_count followers_count following_count media_count status_count  \
# 0           19             257            4404         202          349
# 1           64              10              66           0           13
# 2         5005         1144072            1815        5938        22155
# 3          902             230             201         264         9732
# 4          516               6             121          21          441
# 5           36          184857           55163          89      1047327
# 6            0              69            3743           2            2
# 7           10             247             196          21          729
# 8           17              71             269          47           85
# 9            7             160             304           1          238
# 10          12             277             651           5            9
# 11         149             131             713           1           99
# 12           1              90             559           0           10
# 13           4             167             928           1            5
# 14          11              47             176           0            9
# 15           3             211            1793           5           36
# 16           0             493            1818           0            0
# 17       10492         2610372          212153      159434       348095
# 18         112              42             194          10          209
# 19          83          812573          263503        3286      2368307
# 20           5               1             109           2            3
# 21           6              15              24          28          108
# 22           7             250             742           0            7
# 23         181              92             378          26         1320
# 24         150              81             322           1          292
# 25           3               1               1           0            0
# 26          22            2701            2490          97          336
# 27          21             134             297          34         1815
# 28          12              77              69           3            4
# 29          34             244             260          25         2038
# 30           1            1813            1825           1           81
# 31         145              34             119           4          187
# 32           0              16              39           0            0
# 33           2              62             113           0           86
# 34           2              70             115           1          795
# 35          18              50              69           6         1665
# 36       22594              80             376         330         5186
# 37           6              79             122           3          887
# 38          18             221             252          29        18865
# 39          61             205             333          23         4506
# 40          26              29              86           1          166
#
#    verified
# 0     False
# 1     False
# 2      True
# 3     False
# 4     False
# 5      True
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19     True
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# 32    False
# 33    False
# 34    False
# 35    False
# 36    False
# 37    False
# 38    False
# 39    False
# 40    False

# %%
sum(user_data['verified'] == True)
# Out:
# 3
